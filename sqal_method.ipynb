# %% [markdown]
# <a href="https://colab.research.google.com/github/Subhas333/Project-1/blob/main/sqal_method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Subhas333/Project-1/refs/heads/main/players_20.csv', encoding='latin-1' )

# %%
df.set_index('short_name', inplace=True)

# %%
df
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
# J. Oblak              200389
# E. Hazard             183277
# ...                      ...
# Shao Shuai            245006
# Xiao Mingjie          250995
# Zhang Wei             252332
# Wang Haijian          251110
# Pan Ximing            233449
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# ...                                                              ...
# Shao Shuai         https://sofifa.com/player/245006/shuai-shao/20...
# ...

# %%
df = df[['long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club']]

# %%
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                      éµå¸
#    22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                       å¼ å¨   19  2000-05-16
# Wang Haijian                                 æ±ªæµ·å¥   18  2000-08-02
# Pan Ximing                                   æ½åæ   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
#sample
df['nationality'].sample(10, random_state=99)
# Out:
# short_name
# R. Alvarado               Mexico
# Qiao Wei                China PR
# E. Paredes                 Chile
# K. Stoyanov             Bulgaria
# M. ChudÃ½               Slovakia
# D. Sundaram                India
# R. Gagliardini             Italy
# G. Debeljuh              Croatia
# Kim Seung Yong    Korea Republic
# M. Hansen                Denmark
# Name: nationality, dtype: object

# %%
df.sample(frac=.2 ,random_state=12)
#20% of data frame
# Out:
#                                    long_name  age         dob  height_cm  \
# short_name
# Y. Thoelen                   Yannick Thoelen   28  1990-07-18        188
# M. NadÃ©                      MickaÃ«l NadÃ©   20  1999-03-04        188
# V. GarcÃ­a   VÃ­ctor Hugo GarcÃ­a HernÃ¡ndez   25  1994-06-11        178
# M. Gyamfi                     Maxwell Gyamfi   19  2000-01-18        185
# W. Cyprien                     Wylan Cyprien   24  1995-01-28        180
# ...                                      ...  ...         ...        ...
# H. Kadish                      Hassan Kadish   26  1992-09-26        179
# A. Chapman                     Aaron Chapman   29  1990-05-29        203
# I. Ezekiel                      Imoh Ezekiel   25  1993-10-24        178
# H. Sakai                       é
# äº å®æ¨¹   29  1990-04-12        183
# C. KeÈerÃ¼          Claudiu Andrei KeÈerÃ¼   32  1986-12-02        178
#
#              weight_kg   nationality                    club
# short_name
# ...

# %%
 #unsample frac>1(replace parameter to be true)
df.sample(frac=2 ,replace=True)
# Out:
#                                       long_name  age         dob  height_cm  \
# short_name
# A. Atouchi                        Amine Atouchi   27  1992-01-07        182
# J. Tanganga                     Japhet Tanganga   20  1999-03-31        184
# S. KÄ±rÄ±ntÄ±lÄ±           Serkan KÄ±rÄ±ntÄ±lÄ±   34  1985-02-15        185
# J. Koenraat                       Jari Koenraat   23  1995-09-26        182
# Thiago Silva           Thiago Emiliano da Silva   34  1984-09-22        183
# ...                                         ...  ...         ...        ...
# S. Camara                     Souleymane Camara   36  1982-12-22        174
# H. KavaklÄ±dere              Harun KavaklÄ±dere   21  1998-03-16        172
# P. Parra          Pablo Alejandro Parra Rubilar   25  1994-06-23        175
# C. MacGillivray              Craig MacGillivray   26  1993-01-12        188
# M. Dombrowka                      Max Dombrowka   27  1992-03-24        180
#
# ...

# %%
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                      éµå¸
#    22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                       å¼ å¨   19  2000-05-16
# Wang Haijian                                 æ±ªæµ·å¥   18  2000-08-02
# Pan Ximing                                   æ½åæ   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %% [markdown]
# #Query

# %%
df.query('age > 30')
#player>30
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# L. ModriÄ                                Luka ModriÄ   33  1985-09-09
# G. Chiellini                         Giorgio Chiellini   34  1984-08-14
# S. AgÃ¼ero          Sergio Leonel AgÃ¼ero del Castillo   31  1988-06-02
# ...                                                ...  ...         ...
# Jin Hui                                         é³è¾   31  1988-03-10
# Ge Zhen                                        Zhen Ge   32  1987-06-23
# J. McCombe                              Jamie  McCombe   36  1983-01-01
# G. Maley                                    Gary Maley   36  1982-08-03
# Zhou Ting                                       å¨æº   40  1979-02-05
#
#                    height_cm  weight_kg nationality              club
# short_name
# ...

# %%
#boolean slicing
df[df['age'] > 30]
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# L. ModriÄ                                Luka ModriÄ   33  1985-09-09
# G. Chiellini                         Giorgio Chiellini   34  1984-08-14
# S. AgÃ¼ero          Sergio Leonel AgÃ¼ero del Castillo   31  1988-06-02
# ...                                                ...  ...         ...
# Jin Hui                                         é³è¾   31  1988-03-10
# Ge Zhen                                        Zhen Ge   32  1987-06-23
# J. McCombe                              Jamie  McCombe   36  1983-01-01
# G. Maley                                    Gary Maley   36  1982-08-03
# Zhou Ting                                       å¨æº   40  1979-02-05
#
#                    height_cm  weight_kg nationality              club
# short_name
# ...

# %%
df.query('nationality == "England" & age>30')
# Out:
#                          long_name  age         dob  height_cm  weight_kg  \
# short_name
# J. Vardy               Jamie Vardy   32  1987-01-11        179         74
# J. Milner      James Philip Milner   33  1986-01-04        175         70
# W. Rooney        Wayne Mark Rooney   33  1985-10-24        176         83
# B. Foster               Ben Foster   36  1983-04-03        193         90
# T. Heaton               Tom Heaton   33  1986-04-15        187         92
# ...                            ...  ...         ...        ...        ...
# P. Edwards            Phil Edwards   33  1985-11-08        173         71
# B. Trowley             Ben Trowley   33  1985-12-20        186         85
# S. Tillmanson       Sam Tillmanson   31  1987-07-14        175         68
# N. Hunt                 Nicky Hunt   35  1983-09-03        185         86
# J. McCombe          Jamie  McCombe   36  1983-01-01        196         79
#
#               nationality                club
# short_name
# ...

# %%
df[(df['nationality']=="England") & (df['age']>30)]
# Out:
#                          long_name  age         dob  height_cm  weight_kg  \
# short_name
# J. Vardy               Jamie Vardy   32  1987-01-11        179         74
# J. Milner      James Philip Milner   33  1986-01-04        175         70
# W. Rooney        Wayne Mark Rooney   33  1985-10-24        176         83
# B. Foster               Ben Foster   36  1983-04-03        193         90
# T. Heaton               Tom Heaton   33  1986-04-15        187         92
# ...                            ...  ...         ...        ...        ...
# P. Edwards            Phil Edwards   33  1985-11-08        173         71
# B. Trowley             Ben Trowley   33  1985-12-20        186         85
# S. Tillmanson       Sam Tillmanson   31  1987-07-14        175         68
# N. Hunt                 Nicky Hunt   35  1983-09-03        185         86
# J. McCombe          Jamie  McCombe   36  1983-01-01        196         79
#
#               nationality                club
# short_name
# ...

# %%
#add not operator
df.query('not nationality == "England" and age>30')
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# L. ModriÄ                                Luka ModriÄ   33  1985-09-09
# G. Chiellini                         Giorgio Chiellini   34  1984-08-14
# S. AgÃ¼ero          Sergio Leonel AgÃ¼ero del Castillo   31  1988-06-02
# ...                                                ...  ...         ...
# G. Harkin                                Gareth Harkin   31  1987-12-19
# Jin Hui                                         é³è¾   31  1988-03-10
# Ge Zhen                                        Zhen Ge   32  1987-06-23
# G. Maley                                    Gary Maley   36  1982-08-03
# Zhou Ting                                       å¨æº   40  1979-02-05
#
#                    height_cm  weight_kg          nationality              club
# short_name
# ...

# %%
#datatyes check
df.dtypes
# Out:
# long_name      object
# age             int64
# dob            object
# height_cm       int64
# weight_kg       int64
# nationality    object
# club           object
# dtype: object

# %%
df['dob']=pd.to_datetime(df['dob'])
#changing it
# Out:
# /tmp/ipython-input-3835621688.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dob']=pd.to_datetime(df['dob'])

# %%
df.dtypes
# Out:
# long_name              object
# age                     int64
# dob            datetime64[ns]
# height_cm               int64
# weight_kg               int64
# nationality            object
# club                   object
# dtype: object

# %%
df['dob'].dt.year
# Out:
# short_name
# L. Messi             1987
# Cristiano Ronaldo    1985
# Neymar Jr            1992
# J. Oblak             1993
# E. Hazard            1991
#                      ...
# Shao Shuai           1997
# Xiao Mingjie         1997
# Zhang Wei            2000
# Wang Haijian         2000
# Pan Ximing           1993
# Name: dob, Length: 18278, dtype: int32

# %%
#using query
df.query('dob.dt.year > 1990')
# Out:
#                                    long_name  age        dob  height_cm  \
# short_name
# Neymar Jr      Neymar da Silva Santos Junior   27 1992-02-05        175
# J. Oblak                           Jan Oblak   26 1993-01-07        188
# E. Hazard                        Eden Hazard   28 1991-01-07        175
# K. De Bruyne                 Kevin De Bruyne   28 1991-06-28        181
# M. ter Stegen         Marc-AndrÃ© ter Stegen   27 1992-04-30        187
# ...                                      ...  ...        ...        ...
# Shao Shuai                            éµå¸
#    22 1997-03-10        186
# Xiao Mingjie                    Mingjie Xiao   22 1997-01-01        177
# Zhang Wei                             å¼ å¨   19 2000-05-16        186
# Wang Haijian                       æ±ªæµ·å¥   18 2000-08-02        185
# Pan Ximing                         æ½åæ   26 1993-01-11        182
#
#                weight_kg nationality                           club
# short_name
# ...

# %% [markdown]
# #apply methods

# %%
import numpy as np
df['age'].apply(np.sqrt)
# Out:
# short_name
# L. Messi             5.656854
# Cristiano Ronaldo    5.830952
# Neymar Jr            5.196152
# J. Oblak             5.099020
# E. Hazard            5.291503
#                        ...
# Shao Shuai           4.690416
# Xiao Mingjie         4.690416
# Zhang Wei            4.358899
# Wang Haijian         4.242641
# Pan Ximing           5.099020
# Name: age, Length: 18278, dtype: float64

# %%
def calculateBMI(height_cm, weight_kg):
  return weight_kg / (height_cm/100)**2

# %%
df.apply(lambda row: calculateBMI(row['height_cm'], row['weight_kg']), axis=1)
# Out:
# short_name
# L. Messi             24.913495
# Cristiano Ronaldo    23.735308
# Neymar Jr            22.204082
# J. Oblak             24.615211
# E. Hazard            24.163265
#                        ...
# Shao Shuai           22.835010
# Xiao Mingjie         21.066743
# Zhang Wei            21.678807
# Wang Haijian         21.621622
# Pan Ximing           23.547881
# Length: 18278, dtype: float64

# %% [markdown]
# #copy method

# %%
df
# Out:
#                                              long_name  age        dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   32 1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34 1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27 1992-02-05
# J. Oblak                                     Jan Oblak   26 1993-01-07
# E. Hazard                                  Eden Hazard   28 1991-01-07
# ...                                                ...  ...        ...
# Shao Shuai                                      éµå¸
#    22 1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22 1997-01-01
# Zhang Wei                                       å¼ å¨   19 2000-05-16
# Wang Haijian                                 æ±ªæµ·å¥   18 2000-08-02
# Pan Ximing                                   æ½åæ   26 1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
#copy the df
df_copy = df.copy()

# %%
df_copy
# Out:
#                                              long_name  age        dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   32 1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34 1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27 1992-02-05
# J. Oblak                                     Jan Oblak   26 1993-01-07
# E. Hazard                                  Eden Hazard   28 1991-01-07
# ...                                                ...  ...        ...
# Shao Shuai                                      éµå¸
#    22 1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22 1997-01-01
# Zhang Wei                                       å¼ å¨   19 2000-05-16
# Wang Haijian                                 æ±ªæµ·å¥   18 2000-08-02
# Pan Ximing                                   æ½åæ   26 1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
df.loc['L. Messi', 'age'] = 35

# %%
df
# Out:
#                                              long_name  age        dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   35 1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34 1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27 1992-02-05
# J. Oblak                                     Jan Oblak   26 1993-01-07
# E. Hazard                                  Eden Hazard   28 1991-01-07
# ...                                                ...  ...        ...
# Shao Shuai                                      éµå¸
#    22 1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22 1997-01-01
# Zhang Wei                                       å¼ å¨   19 2000-05-16
# Wang Haijian                                 æ±ªæµ·å¥   18 2000-08-02
# Pan Ximing                                   æ½åæ   26 1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
df_copy
# its diffent age the origanal and new copy cause deep is true will not rflect on copy
# Out:
#                                              long_name  age        dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   32 1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34 1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27 1992-02-05
# J. Oblak                                     Jan Oblak   26 1993-01-07
# E. Hazard                                  Eden Hazard   28 1991-01-07
# ...                                                ...  ...        ...
# Shao Shuai                                      éµå¸
#    22 1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22 1997-01-01
# Zhang Wei                                       å¼ å¨   19 2000-05-16
# Wang Haijian                                 æ±ªæµ·å¥   18 2000-08-02
# Pan Ximing                                   æ½åæ   26 1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
#deep =false
df_copy = df.copy(deep=False)

# %%
df.loc['L. Messi', 'age'] = 36

# %%
df
# Out:
#                                              long_name  age        dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   36 1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34 1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27 1992-02-05
# J. Oblak                                     Jan Oblak   26 1993-01-07
# E. Hazard                                  Eden Hazard   28 1991-01-07
# ...                                                ...  ...        ...
# Shao Shuai                                      éµå¸
#    22 1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22 1997-01-01
# Zhang Wei                                       å¼ å¨   19 2000-05-16
# Wang Haijian                                 æ±ªæµ·å¥   18 2000-08-02
# Pan Ximing                                   æ½åæ   26 1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
df_copy
#change is in both side
# Out:
#                                              long_name  age        dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   36 1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34 1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27 1992-02-05
# J. Oblak                                     Jan Oblak   26 1993-01-07
# E. Hazard                                  Eden Hazard   28 1991-01-07
# ...                                                ...  ...        ...
# Shao Shuai                                      éµå¸
#    22 1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22 1997-01-01
# Zhang Wei                                       å¼ å¨   19 2000-05-16
# Wang Haijian                                 æ±ªæµ·å¥   18 2000-08-02
# Pan Ximing                                   æ½åæ   26 1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...
