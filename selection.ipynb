# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Subhas333/Project-1/refs/heads/main/players_20.csv', encoding='latin-1' )

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi      Lionel AndrÃ©s Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
df.set_index('short_name', inplace=True)

# %%
df
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
# J. Oblak              200389
# E. Hazard             183277
# ...                      ...
# Shao Shuai            245006
# Xiao Mingjie          250995
# Zhang Wei             252332
# Wang Haijian          251110
# Pan Ximing            233449
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# ...                                                              ...
# Shao Shuai         https://sofifa.com/player/245006/shuai-shao/20...
# ...

# %%
df = df[['long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club']].copy()

# %%
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                      éµå¸
#    22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                       å¼ å¨   19  2000-05-16
# Wang Haijian                                 æ±ªæµ·å¥   18  2000-08-02
# Pan Ximing                                   æ½åæ   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %% [markdown]
# #loc
# loc[row][col]

# %%
#get all element of l.messi
df.loc['L. Messi']
# Out:
# long_name      Lionel AndrÃ©s Messi Cuccittini
# age                                         32
# dob                                 1987-06-24
# height_cm                                  170
# weight_kg                                   72
# nationality                          Argentina
# club                              FC Barcelona
# Name: L. Messi, dtype: object

# %%
df.loc['L. Messi','height_cm']
# Out:
# np.int64(170)

# %%
#cristian
df.loc['Cristiano Ronaldo']
# Out:
# long_name      Cristiano Ronaldo dos Santos Aveiro
# age                                             34
# dob                                     1985-02-05
# height_cm                                      187
# weight_kg                                       83
# nationality                               Portugal
# club                                      Juventus
# Name: Cristiano Ronaldo, dtype: object

# %%
df.loc['Cristiano Ronaldo','nationality']
# Out:
# 'Portugal'

# %%
#all valaues
df.loc[:,'nationality']
# Out:
# short_name
# L. Messi             Argentina
# Cristiano Ronaldo     Portugal
# Neymar Jr               Brazil
# J. Oblak              Slovenia
# E. Hazard              Belgium
#                        ...
# Shao Shuai            China PR
# Xiao Mingjie          China PR
# Zhang Wei             China PR
# Wang Haijian          China PR
# Pan Ximing            China PR
# Name: nationality, Length: 18278, dtype: object

# %%
#leo
df.loc['L. Messi',:]
# Out:
# long_name      Lionel AndrÃ©s Messi Cuccittini
# age                                         32
# dob                                 1987-06-24
# height_cm                                  170
# weight_kg                                   72
# nationality                          Argentina
# club                              FC Barcelona
# Name: L. Messi, dtype: object

# %% [markdown]
# #selection with a list of values

# %%
#get all elements of leo and christian
df.loc[['L. Messi','Cristiano Ronaldo']]
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#                    height_cm  weight_kg nationality          club
# short_name
# L. Messi                 170         72   Argentina  FC Barcelona
# Cristiano Ronaldo        187         83    Portugal      Juventus

# %%
#height of them
df.loc[['L. Messi','Cristiano Ronaldo'],'height_cm']
# Out:
# short_name
# L. Messi             170
# Cristiano Ronaldo    187
# Name: height_cm, dtype: int64

# %%
#height and weight
df.loc[['L. Messi','Cristiano Ronaldo'],['height_cm','weight_kg']]
# Out:
#                    height_cm  weight_kg
# short_name
# L. Messi                 170         72
# Cristiano Ronaldo        187         83

# %% [markdown]
# # selection a range with a slice
# start:stop:step

# %%
players=['L. Messi','Cristiano Ronaldo']
df.loc[players,'age':'club']
# Out:
#                    age         dob  height_cm  weight_kg nationality  \
# short_name
# L. Messi            32  1987-06-24        170         72   Argentina
# Cristiano Ronaldo   34  1985-02-05        187         83    Portugal
#
#                            club
# short_name
# L. Messi           FC Barcelona
# Cristiano Ronaldo      Juventus

# %%
#index labels
colums=['age','dob','height_cm','weight_kg']
df.loc[players,colums]
# Out:
#                    age         dob  height_cm  weight_kg
# short_name
# L. Messi            32  1987-06-24        170         72
# Cristiano Ronaldo   34  1985-02-05        187         83

# %% [markdown]
# # selection with conditions

# %%
df.loc[df['height_cm']>180,colums]
# Out:
#                    age         dob  height_cm  weight_kg
# short_name
# Cristiano Ronaldo   34  1985-02-05        187         83
# J. Oblak            26  1993-01-07        188         87
# K. De Bruyne        28  1991-06-28        181         70
# M. ter Stegen       27  1992-04-30        187         85
# V. van Dijk         27  1991-07-08        193         92
# ...                ...         ...        ...        ...
# P. Martin           20  1999-01-05        188         84
# Shao Shuai          22  1997-03-10        186         79
# Zhang Wei           19  2000-05-16        186         75
# Wang Haijian        18  2000-08-02        185         74
# Pan Ximing          26  1993-01-11        182         78
#
# [9744 rows x 4 columns]

# %%
#multi condn
df.loc[(df['height_cm']>180) & (df['weight_kg']>80),colums]
# Out:
#                    age         dob  height_cm  weight_kg
# short_name
# Cristiano Ronaldo   34  1985-02-05        187         83
# J. Oblak            26  1993-01-07        188         87
# M. ter Stegen       27  1992-04-30        187         85
# V. van Dijk         27  1991-07-08        193         92
# K. Koulibaly        28  1991-06-20        187         89
# ...                ...         ...        ...        ...
# B. Sinzig           19  1999-12-21        191         81
# J. Wright           18  2001-04-10        185         82
# D. Mackay           22  1997-01-23        191         81
# P. KrÃ³lczyk        25  1994-05-10        188         81
# P. Martin           20  1999-01-05        188         84
#
# [3781 rows x 4 columns]

# %% [markdown]
# #iloc
# iloc[row,colums]
# columns not includes

# %%
#get height of messi
df.iloc[0,3]
# Out:
# np.int64(170)

# %%
#weight of ronaldo
df.iloc[1,4]
# Out:
# np.int64(83)

# %%
#get all rows inside height
df.iloc[:,3]
# Out:
# short_name
# L. Messi             170
# Cristiano Ronaldo    187
# Neymar Jr            175
# J. Oblak             188
# E. Hazard            175
#                     ...
# Shao Shuai           186
# Xiao Mingjie         177
# Zhang Wei            186
# Wang Haijian         185
# Pan Ximing           182
# Name: height_cm, Length: 18278, dtype: int64

# %%
df.iloc[0,:]
# Out:
# long_name      Lionel AndrÃ©s Messi Cuccittini
# age                                         32
# dob                                 1987-06-24
# height_cm                                  170
# weight_kg                                   72
# nationality                          Argentina
# club                              FC Barcelona
# Name: L. Messi, dtype: object

# %%
#sellecting list of values
df.iloc[[0,1]]
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#                    height_cm  weight_kg nationality          club
# short_name
# L. Messi                 170         72   Argentina  FC Barcelona
# Cristiano Ronaldo        187         83    Portugal      Juventus

# %%
# height of both
df.iloc[[0,1],3]
# Out:
# short_name
# L. Messi             170
# Cristiano Ronaldo    187
# Name: height_cm, dtype: int64

# %%
#height and wt
df.iloc[[0,1],[3,4]]
# Out:
#                    height_cm  weight_kg
# short_name
# L. Messi                 170         72
# Cristiano Ronaldo        187         83

# %%
#range and slice
players=[0,1]
df.iloc[players,3:5]
# Out:
#                    height_cm  weight_kg
# short_name
# L. Messi                 170         72
# Cristiano Ronaldo        187         83

# %%
df.iloc[0:10,3]
# Out:
# short_name
# L. Messi             170
# Cristiano Ronaldo    187
# Neymar Jr            175
# J. Oblak             188
# E. Hazard            175
# K. De Bruyne         181
# M. ter Stegen        187
# V. van Dijk          193
# L. ModriÄ           172
# M. Salah             175
# Name: height_cm, dtype: int64

# %%
# set values in cell
df.iloc[0,3]=178

# %%
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                      éµå¸
#    22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                       å¼ å¨   19  2000-05-16
# Wang Haijian                                 æ±ªæµ·å¥   18  2000-08-02
# Pan Ximing                                   æ½åæ   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
df.iloc[-1,:]=np.nan
#set last row nan

# %%
df
# Out:
#                                              long_name   age         dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior  27.0  1992-02-05
# J. Oblak                                     Jan Oblak  26.0  1993-01-07
# E. Hazard                                  Eden Hazard  28.0  1991-01-07
# ...                                                ...   ...         ...
# Shao Shuai                                      éµå¸
#   22.0  1997-03-10
# Xiao Mingjie                              Mingjie Xiao  22.0  1997-01-01
# Zhang Wei                                       å¼ å¨  19.0  2000-05-16
# Wang Haijian                                 æ±ªæµ·å¥  18.0  2000-08-02
# Pan Ximing                                         NaN   NaN         NaN
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %% [markdown]
# #drop rows or column

# %%
df.drop('L. Messi' ,axis=0)
#axis 0 for row 1 for column
# Out:
#                                              long_name   age         dob  \
# short_name
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior  27.0  1992-02-05
# J. Oblak                                     Jan Oblak  26.0  1993-01-07
# E. Hazard                                  Eden Hazard  28.0  1991-01-07
# K. De Bruyne                           Kevin De Bruyne  28.0  1991-06-28
# ...                                                ...   ...         ...
# Shao Shuai                                      éµå¸
#   22.0  1997-03-10
# Xiao Mingjie                              Mingjie Xiao  22.0  1997-01-01
# Zhang Wei                                       å¼ å¨  19.0  2000-05-16
# Wang Haijian                                 æ±ªæµ·å¥  18.0  2000-08-02
# Pan Ximing                                         NaN   NaN         NaN
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
df.drop(index='Cristiano Ronaldo')
#same as above
# Out:
#                                     long_name   age         dob  height_cm  \
# short_name
# L. Messi      Lionel AndrÃ©s Messi Cuccittini  32.0  1987-06-24      178.0
# Neymar Jr       Neymar da Silva Santos Junior  27.0  1992-02-05      175.0
# J. Oblak                            Jan Oblak  26.0  1993-01-07      188.0
# E. Hazard                         Eden Hazard  28.0  1991-01-07      175.0
# K. De Bruyne                  Kevin De Bruyne  28.0  1991-06-28      181.0
# ...                                       ...   ...         ...        ...
# Shao Shuai                             éµå¸
#   22.0  1997-03-10      186.0
# Xiao Mingjie                     Mingjie Xiao  22.0  1997-01-01      177.0
# Zhang Wei                              å¼ å¨  19.0  2000-05-16      186.0
# Wang Haijian                        æ±ªæµ·å¥  18.0  2000-08-02      185.0
# Pan Ximing                                NaN   NaN         NaN        NaN
#
# ...

# %%
df.drop(['L. Messi','Cristiano Ronaldo'],axis=0,inplace=True)

# %%
df
# Out:
#                                    long_name   age         dob  height_cm  \
# short_name
# Neymar Jr      Neymar da Silva Santos Junior  27.0  1992-02-05      175.0
# J. Oblak                           Jan Oblak  26.0  1993-01-07      188.0
# E. Hazard                        Eden Hazard  28.0  1991-01-07      175.0
# K. De Bruyne                 Kevin De Bruyne  28.0  1991-06-28      181.0
# M. ter Stegen         Marc-AndrÃ© ter Stegen  27.0  1992-04-30      187.0
# ...                                      ...   ...         ...        ...
# Shao Shuai                            éµå¸
#   22.0  1997-03-10      186.0
# Xiao Mingjie                    Mingjie Xiao  22.0  1997-01-01      177.0
# Zhang Wei                             å¼ å¨  19.0  2000-05-16      186.0
# Wang Haijian                       æ±ªæµ·å¥  18.0  2000-08-02      185.0
# Pan Ximing                               NaN   NaN         NaN        NaN
#
# ...

# %%
#drop column
df.drop('height_cm',axis=1,inplace=True)

# %%
df
# Out:
#                                    long_name   age         dob  weight_kg  \
# short_name
# Neymar Jr      Neymar da Silva Santos Junior  27.0  1992-02-05       68.0
# J. Oblak                           Jan Oblak  26.0  1993-01-07       87.0
# E. Hazard                        Eden Hazard  28.0  1991-01-07       74.0
# K. De Bruyne                 Kevin De Bruyne  28.0  1991-06-28       70.0
# M. ter Stegen         Marc-AndrÃ© ter Stegen  27.0  1992-04-30       85.0
# ...                                      ...   ...         ...        ...
# Shao Shuai                            éµå¸
#   22.0  1997-03-10       79.0
# Xiao Mingjie                    Mingjie Xiao  22.0  1997-01-01       66.0
# Zhang Wei                             å¼ å¨  19.0  2000-05-16       75.0
# Wang Haijian                       æ±ªæµ·å¥  18.0  2000-08-02       74.0
# Pan Ximing                               NaN   NaN         NaN        NaN
#
#               nationality                           club
# ...

# %%
df.drop(columns=['long_name'])
# Out:
#                 age         dob  weight_kg nationality  \
# short_name
# Neymar Jr      27.0  1992-02-05       68.0      Brazil
# J. Oblak       26.0  1993-01-07       87.0    Slovenia
# E. Hazard      28.0  1991-01-07       74.0     Belgium
# K. De Bruyne   28.0  1991-06-28       70.0     Belgium
# M. ter Stegen  27.0  1992-04-30       85.0     Germany
# ...             ...         ...        ...         ...
# Shao Shuai     22.0  1997-03-10       79.0    China PR
# Xiao Mingjie   22.0  1997-01-01       66.0    China PR
# Zhang Wei      19.0  2000-05-16       75.0    China PR
# Wang Haijian   18.0  2000-08-02       74.0    China PR
# Pan Ximing      NaN         NaN        NaN         NaN
#
#                                         club
# short_name
# Neymar Jr                Paris Saint-Germain
# J. Oblak                    AtlÃ©tico Madrid
# E. Hazard                        Real Madrid
# K. De Bruyne                 Manchester City
# M. ter Stegen                   FC Barcelona
# ...

# %%
#drop colum by index
df.columns[[5]]
# Out:
# Index(['club'], dtype='object')

# %%
df.drop(df.columns[[-1]],axis=1,inplace=True)

# %%
df
# Out:
#                                    long_name   age         dob  weight_kg  \
# short_name
# Neymar Jr      Neymar da Silva Santos Junior  27.0  1992-02-05       68.0
# J. Oblak                           Jan Oblak  26.0  1993-01-07       87.0
# E. Hazard                        Eden Hazard  28.0  1991-01-07       74.0
# K. De Bruyne                 Kevin De Bruyne  28.0  1991-06-28       70.0
# M. ter Stegen         Marc-AndrÃ© ter Stegen  27.0  1992-04-30       85.0
# ...                                      ...   ...         ...        ...
# Shao Shuai                            éµå¸
#   22.0  1997-03-10       79.0
# Xiao Mingjie                    Mingjie Xiao  22.0  1997-01-01       66.0
# Zhang Wei                             å¼ å¨  19.0  2000-05-16       75.0
# Wang Haijian                       æ±ªæµ·å¥  18.0  2000-08-02       74.0
# Pan Ximing                               NaN   NaN         NaN        NaN
#
#               nationality
# short_name
# ...
