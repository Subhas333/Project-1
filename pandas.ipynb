# %% [markdown]
# <a href="https://colab.research.google.com/github/Subhas333/Project-1/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Creating datafrane from an array

# %% [markdown]
# ## option 1 array

# %%
data = np.array([[1,4],[2,5],[4,5]])

# %%
pd.DataFrame(data)
# Out:
#    0  1
# 0  1  4
# 1  2  5
# 2  4  5

# %%
df =pd.DataFrame(data,index = ['row1','row2','rpw3'],
                 columns=['col1','col2'])

# %%
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# rpw3     4     5

# %% [markdown]
# ## create array with list

# %%
data = [1,4],[2,5],[4,5]
df =pd.DataFrame(data,index = ['row1','row2','rpw3'],
                 columns=['col1','col2'])
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# rpw3     4     5

# %% [markdown]
# # 2. create dataframe with dictionary

# %%
states =['california','kathmandu','new york']
population=[2345,1223,12256]

# %% [markdown]
# ###storing list in dictionary

# %%
dict_states ={'states':states,'population':population}

# %% [markdown]
# ###dataframe create

# %%
df_population=pd.DataFrame(dict_states)

# %%
df_population
# Out:
#        states  population
# 0  california        2345
# 1   kathmandu        1223
# 2    new york       12256

# %% [markdown]
# #3 Creating dataframe with csv file

# %%
df_exams= pd.read_csv('/StudentsPerformance.csv')

# %%
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
import kagglehub
path = kagglehub.dataset_download("mlg-ulb/creditcardfraud")
# Out:
# Using Colab cache for faster access to the 'creditcardfraud' dataset.

# %%
import os
dfab=pd.read_csv(os.path.join(path, 'creditcard.csv'))

# %%
dfab.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# # showing limited sets of rows

# %%
df_exams.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df_exams.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
df_exams.shape
# Out:
# (1000, 8)

# %%
pd.set_option('display.max_rows',1000)

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
df_exams.iloc[200:301]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 200  female        group C          associate's degree      standard
# 201  female        group D                some college  free/reduced
# 202    male        group C          associate's degree      standard
# 203  female        group B          associate's degree      standard
# 204    male        group C                some college      standard
# 205    male        group D            some high school      standard
# 206    male        group E           bachelor's degree      standard
# 207    male        group E                 high school      standard
# 208  female        group B                some college  free/reduced
# 209  female        group B                some college  free/reduced
# 210    male        group D            some high school  free/reduced
# 211    male        group C                some college  free/reduced
# 212  female        group C                 high school  free/reduced
# ...

# %%
df_exams.iloc[24:30,:2]
# Out:
#     gender race/ethnicity
# 24    male        group D
# 25    male        group A
# 26    male        group B
# 27  female        group C
# 28    male        group C
# 29  female        group D

# %%
df_exams.iloc[24:30,:6]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 24    male        group D           bachelor's degree  free/reduced
# 25    male        group A             master's degree  free/reduced
# 26    male        group B                some college      standard
# 27  female        group C           bachelor's degree      standard
# 28    male        group C                 high school      standard
# 29  female        group D             master's degree      standard
#
#    test preparation course  math score
# 24               completed          74
# 25                    none          73
# 26                    none          69
# 27                    none          67
# 28                    none          70
# 29                    none          62

# %%
df_exams.loc[244:300]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 244    male        group D            some high school      standard
# 245    male        group C          associate's degree      standard
# 246    male        group E          associate's degree      standard
# 247  female        group B                 high school      standard
# 248  female        group B                 high school      standard
# 249    male        group C                 high school      standard
# 250    male        group A            some high school      standard
# 251  female        group D                some college  free/reduced
# 252  female        group B            some high school      standard
# 253    male        group D             master's degree      standard
# 254    male        group D                 high school      standard
# 255  female        group E                some college      standard
# 256  female        group C          associate's degree  free/reduced
# ...

# %% [markdown]
# # atrributes
# A value associated with object(reference by name using dotted )\
# df.columns

# %%
df_exams.index #index access
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# access to column attributes
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df_exams.dtypes #columns types
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# #methods are
# 1.head \
# 2.info etc

# %%
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# # functions

# %%
len(df_exams)
# Out:
# 1000

# %%
max(df_exams.index)
# Out:
# 999

# %%
type(df_exams)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# roundoff in dataset

# %%
round(df_exams, 2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %% [markdown]
# # selecting columns

# %%
df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
# 5      female
# 6      female
# 7        male
# 8        male
# 9      female
# 10       male
# 11       male
# 12     female
# 13       male
# 14     female
# 15     female
# 16       male
# 17     female
# 18       male
# 19     female
# 20       male
# 21     female
# 22       male
# 23     female
# 24       male
# 25       male
# 26       male
# 27     female
# 28       male
# 29     female
# 30     female
# 31     female
# 32     female
# 33       male
# 34       male
# 35       male
# 36     female
# 37     female
# 38     female
# 39       male
# 40       male
# 41     female
# 42     female
# 43       male
# 44     female
# 45       male
# 46     female
# 47     female
# 48     female
# 49       male
# 50       male
# 51       male
# 52       male
# 53       male
# 54     female
# 55     female
# 56     female
# 57       male
# 58       male
# 59     female
# 60       male
# 61       male
# ...

# %%
df_exams['gender']=='male' # checking male or not
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
# 5      False
# 6      False
# 7       True
# 8       True
# 9      False
# 10      True
# 11      True
# 12     False
# 13      True
# 14     False
# 15     False
# 16      True
# 17     False
# 18      True
# 19     False
# 20      True
# 21     False
# 22      True
# 23     False
# 24      True
# 25      True
# 26      True
# 27     False
# 28      True
# 29     False
# 30     False
# 31     False
# 32     False
# 33      True
# 34      True
# 35      True
# 36     False
# 37     False
# 38     False
# 39      True
# 40      True
# 41     False
# 42     False
# 43      True
# 44     False
# 45      True
# 46     False
# 47     False
# 48     False
# 49      True
# 50      True
# 51      True
# 52      True
# 53      True
# 54     False
# 55     False
# 56     False
# 57      True
# 58      True
# 59     False
# 60      True
# 61      True
# 62      True
# 63     False
# 64     False
# 65      True
# ...

# %%
df_exams[df_exams['gender']=='male'] #displaying male only
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 13    male        group A                some college      standard
# 16    male        group C                 high school      standard
# 18    male        group C             master's degree  free/reduced
# 20    male        group D                 high school      standard
# 22    male        group D                some college      standard
# 24    male        group D           bachelor's degree  free/reduced
# 25    male        group A             master's degree  free/reduced
# ...

# %%
df_exams[['gender' , 'math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# 5    female          71
# 6    female          88
# 7      male          40
# 8      male          64
# 9    female          38
# 10     male          58
# 11     male          40
# 12   female          65
# 13     male          78
# 14   female          50
# 15   female          69
# 16     male          88
# 17   female          18
# 18     male          46
# 19   female          54
# 20     male          66
# 21   female          65
# 22     male          44
# 23   female          69
# 24     male          74
# 25     male          73
# 26     male          69
# 27   female          67
# 28     male          70
# 29   female          62
# 30   female          69
# 31   female          63
# 32   female          56
# 33     male          40
# 34     male          97
# 35     male          81
# 36   female          74
# ...

# %%
type(df_exams[['gender' , 'math score']])
# Out:
# pandas.core.frame.DataFrame
