# %%
import pandas as pd
import numpy as np

# %%
df_laptops = pd.read_csv('https://raw.githubusercontent.com/Subhas333/Project-1/main/laptop_price.csv', encoding='latin-1')

# %%
df_laptops.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %% [markdown]
# ###create condn and value variables on +2 choices

# %%
condn=[df_laptops['Price_euros']>3000,
       (df_laptops['Price_euros']>2000 ) &(df_laptops['Price_euros']<3000),
       (df_laptops['Price_euros']>1000 ) &(df_laptops['Price_euros']<2000),
                                           df_laptops['Price_euros']<1000

        ]
values= ['too expensive','ecpensive','Affortable','cheap']

# %%
df_laptops['Price_category'] = np.select(condn, values, default='Unknown')

# %%
df_laptops
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df_laptops['Price_category'].value_counts()
# Out:
# Price_category
# cheap            682
# Affortable       483
# ecpensive        118
# too expensive     19
# Unknown            1
# Name: count, dtype: int64

# %% [markdown]
# # exercise : inch size =too big ,big,small,too small

# %%
condn= [
    df_laptops['Inches']>=16,
    (df_laptops['Inches']>=14) & (df_laptops['Inches']<16),
    (df_laptops['Inches']>=12) & (df_laptops['Inches']<14),
    df_laptops['Inches']<12
]
values= ['too big','big','small','too small']

# %%
df_laptops['Inch_category'] = np.select(condn, values, default='Unknown')

# %%
df_laptops.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df_laptops['Inch_category'].value_counts()
# Out:
# Inch_category
# big          871
# small        228
# too big      166
# too small     38
# Name: count, dtype: int64

# %% [markdown]
# # isin(): SINGLE FILTERING

# %%
df_laptops[df_laptops['Company'].isin(['Apple','HP'])]
#filtering
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 0             1   Apple                          MacBook Pro  Ultrabook
# 1             2   Apple                          Macbook Air  Ultrabook
# 2             3      HP                               250 G6   Notebook
# 3             4   Apple                          MacBook Pro  Ultrabook
# 4             5   Apple                          MacBook Pro  Ultrabook
# ...         ...     ...                                  ...        ...
# 1282       1300      HP                     Stream 11-Y000na    Netbook
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1294       1312      HP                  Pavilion 15-AW003nv   Notebook
# 1296       1314      HP                     Stream 11-Y000na    Netbook
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
#
#       Inches                    ScreenResolution  \
# 0       13.3  IPS Panel Retina Display 2560x1600
# ...

# %%
#multiple choices
filter1=df_laptops['TypeName'].isin(['Notebook','Ultrabook'])
filter2=df_laptops['Company'].isin(['Apple','HP'])

# %%
df_laptops[filter1 & filter2]
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 0             1   Apple                          MacBook Pro  Ultrabook
# 1             2   Apple                          Macbook Air  Ultrabook
# 2             3      HP                               250 G6   Notebook
# 3             4   Apple                          MacBook Pro  Ultrabook
# 4             5   Apple                          MacBook Pro  Ultrabook
# ...         ...     ...                                  ...        ...
# 1273       1291      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1280       1298      HP                  Pavilion 15-AW003nv   Notebook
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1294       1312      HP                  Pavilion 15-AW003nv   Notebook
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
#
#       Inches                    ScreenResolution                         Cpu  \
# ...

# %% [markdown]
# # duplicated

# %%
df_laptops.duplicated('laptop_ID')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Length: 1303, dtype: bool

# %%
#showing duplicated data frames if have
df_laptops[df_laptops.duplicated('laptop_ID')]
# Out:
# Empty DataFrame
# Columns: [laptop_ID, Company, Product, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price_euros, Price_category, Inch_category]
# Index: []

# %%
duplicate=df_laptops.duplicated(['Product','TypeName','Inches'])

# %%
df_laptops[duplicate].sort_values(by=['Product' ,'TypeName'])
# Out:
#       laptop_ID Company                              Product  \
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1098       1113      HP                               250 G5
# 1170       1188      HP                               250 G5
# 10           11      HP                               250 G6
# ...         ...     ...                                  ...
# 414         421    Asus                         ZenBook Flip
# 826         835    Asus                         ZenBook Flip
# 1275       1293    Asus                 ZenBook UX305CA-UBM1
# 1289       1307    Asus                 ZenBook UX305CA-UBM1
# 676         684    Asus                            Zenbook 3
#
#                 TypeName  Inches                           ScreenResolution  \
# 1287            Notebook    15.6                                   1366x768
# 1301            Notebook    15.6                                   1366x768
# ...

# %%
df_laptops[duplicate].sort_values(by=['Product' ,'TypeName'])
# Out:
#       laptop_ID Company                              Product  \
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1098       1113      HP                               250 G5
# 1170       1188      HP                               250 G5
# 10           11      HP                               250 G6
# ...         ...     ...                                  ...
# 414         421    Asus                         ZenBook Flip
# 826         835    Asus                         ZenBook Flip
# 1275       1293    Asus                 ZenBook UX305CA-UBM1
# 1289       1307    Asus                 ZenBook UX305CA-UBM1
# 676         684    Asus                            Zenbook 3
#
#                 TypeName  Inches                           ScreenResolution  \
# 1287            Notebook    15.6                                   1366x768
# 1301            Notebook    15.6                                   1366x768
# ...

# %% [markdown]
# ### find the cheapesr and most expensive lapptop annd use sort_values()and suplicate methods (keeep 'first','last'and False )

# %%
df_laptops=df_laptops.sort_values(['Company','Price_euros'])
df_laptops
# Out:
#       laptop_ID Company                           Product   TypeName  Inches  \
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome    Netbook    11.6
# 290         295    Acer              Chromebook C910-C2ST   Notebook    15.6
# 1102       1117    Acer                     Chromebook 15   Notebook    15.6
# 695         703    Acer                 TravelMate B117-M    Netbook    11.6
# 1198       1216    Acer                          Aspire 3   Notebook    15.6
# ...         ...     ...                               ...        ...     ...
# 191         195    Vero     K147 (N3350/4GB/32GB/FHD/W10)   Notebook    14.0
# 877         888  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 192         196  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 184         188  Xiaomi                       Mi Notebook   Notebook    15.6
# 514         521  Xiaomi                       Mi Notebook   Notebook    15.6
#
# ...

# %%
df_laptops.value_counts('Company')
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# LG             3
# Google         3
# Huawei         2
# Name: count, dtype: int64

# %%
duplicated_first=df_laptops.duplicated('Company')

# %%
df_laptops[duplicated_first]
df_laptops[~duplicated_first][['Company','Price_euros']]
# here cheapest are only shown as keep first
# Out:
#         Company  Price_euros
# 1215       Acer       174.00
# 1         Apple       898.94
# 20         Asus       191.90
# 30        Chuwi       244.99
# 340        Dell       274.90
# 983     Fujitsu       649.00
# 472      Google      1275.00
# 1268         HP       209.00
# 170      Huawei      1349.00
# 909          LG      1899.00
# 1272     Lenovo       229.00
# 1169        MSI       839.00
# 626    Mediacom       239.00
# 457   Microsoft       989.00
# 1117      Razer      1029.00
# 430     Samsung       269.00
# 159     Toshiba       447.00
# 1120       Vero       196.00
# 877      Xiaomi       935.00

# %%
# keep last
dublicates_last=df_laptops.duplicated('Company',keep='last')
df_laptops[dublicates_last]
# Out:
#       laptop_ID Company                           Product   TypeName  Inches  \
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome    Netbook    11.6
# 290         295    Acer              Chromebook C910-C2ST   Notebook    15.6
# 1102       1117    Acer                     Chromebook 15   Notebook    15.6
# 695         703    Acer                 TravelMate B117-M    Netbook    11.6
# 1198       1216    Acer                          Aspire 3   Notebook    15.6
# ...         ...     ...                               ...        ...     ...
# 791         800    Vero         K146 (N3350/4GB/32GB/W10)   Notebook    14.0
# 1041       1055    Vero      V142 (X5-Z8350/2GB/32GB/W10)   Notebook    14.0
# 877         888  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 192         196  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 184         188  Xiaomi                       Mi Notebook   Notebook    15.6
#
# ...

# %%
df_laptops[~dublicates_last][['Company','Price_euros']]
# Out:
#         Company  Price_euros
# 1189       Acer      2599.00
# 17        Apple      2858.00
# 1066       Asus      3975.00
# 421       Chuwi       449.00
# 723        Dell      3659.40
# 623     Fujitsu       799.00
# 437      Google      2199.00
# 749          HP      4389.00
# 214      Huawei      1499.00
# 678          LG      2299.00
# 610      Lenovo      4899.00
# 177         MSI      2799.00
# 580    Mediacom       389.00
# 449   Microsoft      2589.00
# 196       Razer      6099.00
# 874     Samsung      1849.00
# 491     Toshiba      2799.00
# 191        Vero       260.00
# 514      Xiaomi      1399.95

# %%
# keep false
df_laptops[df_laptops.duplicated('Company',keep=False)]
# Out:
#       laptop_ID Company                           Product   TypeName  Inches  \
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome    Netbook    11.6
# 290         295    Acer              Chromebook C910-C2ST   Notebook    15.6
# 1102       1117    Acer                     Chromebook 15   Notebook    15.6
# 695         703    Acer                 TravelMate B117-M    Netbook    11.6
# 1198       1216    Acer                          Aspire 3   Notebook    15.6
# ...         ...     ...                               ...        ...     ...
# 191         195    Vero     K147 (N3350/4GB/32GB/FHD/W10)   Notebook    14.0
# 877         888  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 192         196  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 184         188  Xiaomi                       Mi Notebook   Notebook    15.6
# 514         521  Xiaomi                       Mi Notebook   Notebook    15.6
#
# ...

# %%
df_laptops
# Out:
#       laptop_ID Company                           Product   TypeName  Inches  \
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome    Netbook    11.6
# 290         295    Acer              Chromebook C910-C2ST   Notebook    15.6
# 1102       1117    Acer                     Chromebook 15   Notebook    15.6
# 695         703    Acer                 TravelMate B117-M    Netbook    11.6
# 1198       1216    Acer                          Aspire 3   Notebook    15.6
# ...         ...     ...                               ...        ...     ...
# 191         195    Vero     K147 (N3350/4GB/32GB/FHD/W10)   Notebook    14.0
# 877         888  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 192         196  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 184         188  Xiaomi                       Mi Notebook   Notebook    15.6
# 514         521  Xiaomi                       Mi Notebook   Notebook    15.6
#
# ...

# %% [markdown]
# # drop
# ## remove duplicated value

# %%
df_laptops.drop_duplicates(['Company'])[['Company','Price_euros']]
# Out:
#         Company  Price_euros
# 1215       Acer       174.00
# 1         Apple       898.94
# 20         Asus       191.90
# 30        Chuwi       244.99
# 340        Dell       274.90
# 983     Fujitsu       649.00
# 472      Google      1275.00
# 1268         HP       209.00
# 170      Huawei      1349.00
# 909          LG      1899.00
# 1272     Lenovo       229.00
# 1169        MSI       839.00
# 626    Mediacom       239.00
# 457   Microsoft       989.00
# 1117      Razer      1029.00
# 430     Samsung       269.00
# 159     Toshiba       447.00
# 1120       Vero       196.00
# 877      Xiaomi       935.00

# %%
df_laptops.drop_duplicates(['Company'])[['Company','Price_euros']].value_counts('Company')
# Out:
# Company
# Acer         1
# Apple        1
# Asus         1
# Chuwi        1
# Dell         1
# Fujitsu      1
# Google       1
# HP           1
# Huawei       1
# LG           1
# Lenovo       1
# MSI          1
# Mediacom     1
# Microsoft    1
# Razer        1
# Samsung      1
# Toshiba      1
# Vero         1
# Xiaomi       1
# Name: count, dtype: int64

# %%
#finding cheapesr and most expensive laptops
df_laptops=df_laptops.sort_values(['Company','Price_euros'])

# %%
df_laptops.drop_duplicates(['Company'],keep='last')
#expensive one
# Out:
#       laptop_ID    Company                        Product     TypeName  \
# 1189       1207       Acer                Predator G9-793       Gaming
# 17           18      Apple                    MacBook Pro    Ultrabook
# 1066       1081       Asus                     ROG G701VO       Gaming
# 421         428      Chuwi                   LapBook 12.3     Notebook
# 723         731       Dell                   Alienware 17       Gaming
# 623         630    Fujitsu                  LifeBook A557     Notebook
# 437         444     Google                Pixelbook (Core    Ultrabook
# 749         758         HP                       Zbook 17  Workstation
# 214         219     Huawei                     MateBook X    Ultrabook
# 678         686         LG                    Gram 15Z975    Ultrabook
# 610         617     Lenovo                   Thinkpad P51     Notebook
# 177         181        MSI                GT80S 6QF-074US       Gaming
# ...

# %%
df_laptops.drop_duplicates(['Company'],keep='first')
#cheap
# Out:
#       laptop_ID    Company                           Product   TypeName  \
# 1215       1233       Acer  C740-C9QX (3205U/2GB/32GB/Chrome    Netbook
# 1             2      Apple                       Macbook Air  Ultrabook
# 20           21       Asus                   Vivobook E200HA    Netbook
# 30           31      Chuwi                     LapBook 15.6"   Notebook
# 340         346       Dell                     Inspiron 3552   Notebook
# 983         997    Fujitsu                     LifeBook A556   Notebook
# 472         479     Google                   Pixelbook (Core  Ultrabook
# 1268       1286         HP                  Stream 11-Y000na    Netbook
# 170         174     Huawei                        MateBook X  Ultrabook
# 909         922         LG                       Gram 14Z970  Ultrabook
# 1272       1290     Lenovo                IdeaPad 100S-14IBR   Notebook
# 1169       1187        MSI                          PL60 7RD     Gaming
# ...

# %%
df_laptops.drop_duplicates(['Company'],keep='first',ignore_index=True)
#ignore_index=True gives new index
# Out:
#     laptop_ID    Company                           Product   TypeName  Inches  \
# 0        1233       Acer  C740-C9QX (3205U/2GB/32GB/Chrome    Netbook    11.6
# 1           2      Apple                       Macbook Air  Ultrabook    13.3
# 2          21       Asus                   Vivobook E200HA    Netbook    11.6
# 3          31      Chuwi                     LapBook 15.6"   Notebook    15.6
# 4         346       Dell                     Inspiron 3552   Notebook    15.6
# 5         997    Fujitsu                     LifeBook A556   Notebook    15.6
# 6         479     Google                   Pixelbook (Core  Ultrabook    12.3
# 7        1286         HP                  Stream 11-Y000na    Netbook    11.6
# 8         174     Huawei                        MateBook X  Ultrabook    13.0
# 9         922         LG                       Gram 14Z970  Ultrabook    14.0
# 10       1290     Lenovo                IdeaPad 100S-14IBR   Notebook    14.0
# ...

# %% [markdown]
# #1. unique()
# return unique values of series object.(unique are returned in order of apperance)

# %%
# get unique element of company
df_laptops['Company'].unique()
# Out:
# array(['Acer', 'Apple', 'Asus', 'Chuwi', 'Dell', 'Fujitsu', 'Google',
#        'HP', 'Huawei', 'LG', 'Lenovo', 'MSI', 'Mediacom', 'Microsoft',
#        'Razer', 'Samsung', 'Toshiba', 'Vero', 'Xiaomi'], dtype=object)

# %%
# get unique element of inches
df_laptops['Inches'].unique()
# Out:
# array([11.6, 15.6, 14. , 17.3, 13.3, 12. , 15.4, 14.1, 12.5, 12.3, 15. ,
#        17. , 13. , 10.1, 13.9, 11.3, 18.4, 13.5])

# %%
len(df_laptops['Company'].unique())
# Out:
# 19

# %% [markdown]
# #2.nuniquw()
# returns no. of elements in obj excludes NA values by defaults

# %%
df_laptops['Company'].nunique()
# Out:
# 19
